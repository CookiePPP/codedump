# %%
for current_iteration in range(0,100000,1000):
    print(f"iteration {current_iteration:7}: DFR = {min(0.000010 * max(current_iteration-5000,0), 0.20):.2f}")
# Out:
# iteration       0: DFR = 0.00
# iteration    1000: DFR = 0.00
# iteration    2000: DFR = 0.00
# iteration    3000: DFR = 0.00
# iteration    4000: DFR = 0.00
# iteration    5000: DFR = 0.00
# iteration    6000: DFR = 0.01
# iteration    7000: DFR = 0.02
# iteration    8000: DFR = 0.03
# iteration    9000: DFR = 0.04
# iteration   10000: DFR = 0.05
# iteration   11000: DFR = 0.06
# iteration   12000: DFR = 0.07
# iteration   13000: DFR = 0.08
# iteration   14000: DFR = 0.09
# iteration   15000: DFR = 0.10
# iteration   16000: DFR = 0.11
# iteration   17000: DFR = 0.12
# iteration   18000: DFR = 0.13
# iteration   19000: DFR = 0.14
# iteration   20000: DFR = 0.15
# iteration   21000: DFR = 0.16
# iteration   22000: DFR = 0.17
# iteration   23000: DFR = 0.18
# iteration   24000: DFR = 0.19
# iteration   25000: DFR = 0.20
# iteration   26000: DFR = 0.20
# iteration   27000: DFR = 0.20
# iteration   28000: DFR = 0.20
# iteration   29000: DFR = 0.20
# iteration   30000: DFR = 0.20
# ...
